# %% [markdown]
# # Report

# %% [markdown]
# ### INTRODUCTION
#
# New York City is a popular destination for both business and tourism, it is also the most densely populated city in the USA. The city boasts as the financial capital and is home to millions of people who work in the city and who in turn seek opportunities to wind down from their work days.
# This poses great opportunity for anyone who is considerring recreational hang out spots and bars, however there are already many of these spots in the city and therefore one must make use of data analysis to consider whether one's idea will work.
# The purpose of this report is to consider where in New York will be the best location to open a Pool Hall.
#
# ### Business Problem
# The city of New York is known for its world class bars and pool halls. A client may approach me to consider opening a pool hall in the city, however as ther is already many pool halls in the city, we need to evaluate whether the idea is feesable and where would be the best location to open this pool hall, not only so that we can enjoy immediate success but also ensure the longevity of the business.

# %% [markdown]
# ### Data
# The data that I will be using for this capstone project is to determine the best location to open a Pool Hall in the New York area.
# I will be using the Foursquare venues categories to obtain my data as well as a data set that is freely available on geo.nyu.edu so that I can scrape the location coordinates and neighbourhood data from there.
# The api key that I will be using from foursquare is: 4bf58dd8d48988d1e3931735
# The data that I will be using is mostly structured and I will have to make small modifications to the data here and there to fit my model.

# %% [markdown]
# ### Methodology
#
# ##### Step 1
#
# Importing of libraries:
# I imported all the lbraries that I needed to perform the data analysis. The most important being numpy and pandas. I also used geocoders for my maps as well as folium.
#
# ##### Step 2
#
# Downloading and exploring the datasets:
# I used a free dataset to scrape information around location coordinates which can be found on geo.nyu.edu
#
# ##### Step 3
#
# I transferred the data into a pandas dataframe
#
# ##### Step 4
#
# I will be using the Foursquare venues categories to obtain my data as well as a data set that is freely available on geo.nyu.edu so that I can scrape the location coordinates and neighbourhood data from there. The api key that I will be using from foursquare is: 4bf58dd8d48988d1e3931735 The data that I will be using is mostly structured and I will have to make small modifications to the data here and there to fit my model.
#
# ##### Step 5
#
# I drew up a table which list the amounts of venues in the area to see which areas have the least pool halls and from there one can make the assumption that an area needs a pool hall.

# %% [markdown]
# ### Findings

# %% [markdown]
# ![.JPG](attachment:Capture.JPG)Capture

# %% [markdown]
# From the table above one can see that there are multiple areas where there are one or less pool halls, this means that one can consider any one of these areas to open your pool hall, it would be even better if one can get access to financial data in the areas and overlay this to see which are the more affluent areas and then base your descion on this information.
